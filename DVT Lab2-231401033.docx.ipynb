# %% [markdown]
# <a href="https://colab.research.google.com/github/Govarthan30/DVT-30/blob/main/ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

marks = pd.Series(
    [88, 92, 79, 95],
    index=['Anu', 'Ravi', 'Sam', 'Devi']
)

print(marks)   # 92
# Out:
# Anu     88
# Ravi    92
# Sam     79
# Devi    95
# dtype: int64

# %%
data = {
    'Name': ['Anu', 'Ravi', 'Sam'],
    'Marks': [88, 92, 79],
    'Dept': ['CSBS', 'CSBS', 'IT']
}

df = pd.DataFrame(data)

df
# Out:
#    Name  Marks  Dept
# 0   Anu     88  CSBS
# 1  Ravi     92  CSBS
# 2   Sam     79    IT

# %%
df[df['Marks']>90]['Dept']
# Out:
# 1    CSBS
# Name: Dept, dtype: object

# %%
df['Marks']
# Out:
# 0    88
# 1    92
# 2    79
# Name: Marks, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('heart.csv')

df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
print("Top 2 Rows:")
df.head(2)
# Out:
# Top 2 Rows:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0

# %%
print("Bottom 2 Rows:")
df.tail(2)
# Out:
# Bottom 2 Rows:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
print(f"Rows,columns: {df.shape}")
print()
print("Dataset info:")
df.info()
print()
print("Dataset description:")
df.describe()
print()
print(f"Dataset columns: {df.columns}")
df.dtypes
# Out:
# Rows,columns: (1025, 14)
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
#
# Dataset description:
#
# Dataset columns: Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
col = df.columns

for i in col:
  print(f"Number of null in {i} is {df[i].isnull().sum()}")
# Out:
# Number of null in age is 0
# Number of null in sex is 0
# Number of null in cp is 0
# Number of null in trestbps is 0
# Number of null in chol is 0
# Number of null in fbs is 0
# Number of null in restecg is 0
# Number of null in thalach is 0
# Number of null in exang is 0
# Number of null in oldpeak is 0
# Number of null in slope is 0
# Number of null in ca is 0
# Number of null in thal is 0
# Number of null in target is 0

# %%
df["cp"].fillna(df["cp"].mean())
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    0
# 1024    0
# Name: cp, Length: 1025, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    0
# 1024    0
# Name: cp, Length: 1025, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Check for duplicate rows
print("\nDuplicate Rows:")
print(df.duplicated().sum())

# Remove duplicate rows if any exist
df = df.drop_duplicates()

# Check the data type of each column
print("\nData Types:")
print(df.dtypes)

# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Detect outliers using the IQR method
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

outliers = ((df < (Q1 - 1.5 * IQR)) |
            (df > (Q3 + 1.5 * IQR)))

print("\nOutliers in Each Column:")
print(outliers.sum())

# Standardize continuous numerical features
scaler = StandardScaler()

numerical_columns = [
    "age",
    "trestbps",
    "chol",
    "thalach",
    "oldpeak"
]

df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# Display the scaled values
print("\nScaled Numerical Features:")
print(df[numerical_columns].head())

# Check the distribution of the target variable
print("\nTarget Class Distribution:")
print(df["target"].value_counts())
# Out:
# Duplicate Rows:
# 0
#
# Data Types:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object
#
# Summary Statistics:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# ...
